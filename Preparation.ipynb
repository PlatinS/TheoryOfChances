# %%
import pandas as pd

# %%
nm_c1=['tconst','titleType','primaryTitle','startYear','genres']
df = pd.read_csv("data_b.tsv",sep='\t',usecols=nm_c1,keep_default_na = False,na_values='\\N')

# %%
df.shape
# Out:
# (6595083, 5)

# %%
df.head()
# Out:
#       tconst titleType            primaryTitle  startYear  \
# 0  tt0000001     short              Carmencita     1894.0
# 1  tt0000002     short  Le clown et ses chiens     1892.0
# 2  tt0000003     short          Pauvre Pierrot     1892.0
# 3  tt0000004     short             Un bon bock     1892.0
# 4  tt0000005     short        Blacksmith Scene     1893.0
#
#                      genres
# 0         Documentary,Short
# 1           Animation,Short
# 2  Animation,Comedy,Romance
# 3           Animation,Short
# 4              Comedy,Short

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6595083 entries, 0 to 6595082
# Data columns (total 5 columns):
# tconst          object
# titleType       object
# primaryTitle    object
# startYear       float64
# genres          object
# dtypes: float64(1), object(4)
# memory usage: 251.6+ MB

# %%
# df['startYear'] = pd.to_numeric(df['startYear'])
df.isnull().sum()
# Out:
# tconst               0
# titleType            0
# primaryTitle         0
# startYear       441518
# genres          517802
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5687801 entries, 0 to 6595082
# Data columns (total 5 columns):
# tconst          object
# titleType       object
# primaryTitle    object
# startYear       float64
# genres          object
# dtypes: float64(1), object(4)
# memory usage: 260.4+ MB

# %%
df1['startYear']=df1.startYear.astype('int16')
# Out:
# C:\Users\samia\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.head()
# Out:
#       tconst titleType            primaryTitle  startYear  \
# 0  tt0000001     short              Carmencita       1894
# 1  tt0000002     short  Le clown et ses chiens       1892
# 2  tt0000003     short          Pauvre Pierrot       1892
# 3  tt0000004     short             Un bon bock       1892
# 4  tt0000005     short        Blacksmith Scene       1893
#
#                      genres
# 0         Documentary,Short
# 1           Animation,Short
# 2  Animation,Comedy,Romance
# 3           Animation,Short
# 4              Comedy,Short

# %%
df1.titleType.unique()
# Out:
# array(['short', 'movie', 'tvMovie', 'tvSeries', 'tvEpisode', 'tvShort',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
df2 = df1.loc[(df1['titleType'] == 'movie') | (df1['titleType'] == 'tvMovie') | (df1['titleType'] == 'video'), :]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768613 entries, 8 to 6595033
# Data columns (total 5 columns):
# tconst          768613 non-null object
# titleType       768613 non-null object
# primaryTitle    768613 non-null object
# startYear       768613 non-null int16
# genres          768613 non-null object
# dtypes: int16(1), object(4)
# memory usage: 30.8+ MB

# %%
df3 = df2.loc[(df2['startYear'] > 1949), :]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719328 entries, 15494 to 6595033
# Data columns (total 5 columns):
# tconst          719328 non-null object
# titleType       719328 non-null object
# primaryTitle    719328 non-null object
# startYear       719328 non-null int16
# genres          719328 non-null object
# dtypes: int16(1), object(4)
# memory usage: 28.8+ MB

# %%
df3.head()
# Out:
#           tconst titleType       primaryTitle  startYear  \
# 15494  tt0015724     movie      Dama de noche       1993
# 16664  tt0016906     movie         Frivolinas       2014
# 21282  tt0021617     movie  Arizona Territory       1950
# 21719  tt0022064     movie      Lebbra bianca       1951
# 22949  tt0023331     movie    Pesn o geroyakh       1983
#
#                          genres
# 15494     Drama,Mystery,Romance
# 16664            Comedy,Musical
# 21282  Action,Adventure,Western
# 21719                     Drama
# 22949               Documentary

# %%
df3.to_csv("data_bf.csv",index=False)

# %%
dfr = pd.read_csv("data_r.tsv",sep='\t')

# %%
dfr.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1589
# 1  tt0000002            6.1       192
# 2  tt0000003            6.5      1252
# 3  tt0000004            6.2       119
# 4  tt0000005            6.1      2008

# %%
df4 = df3.merge(dfr, how='left')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719328 entries, 0 to 719327
# Data columns (total 7 columns):
# tconst           719328 non-null object
# titleType        719328 non-null object
# primaryTitle     719328 non-null object
# startYear        719328 non-null int16
# genres           719328 non-null object
# averageRating    310234 non-null float64
# numVotes         310234 non-null float64
# dtypes: float64(2), int16(1), object(4)
# memory usage: 39.8+ MB

# %%
df4.isnull().sum()
# Out:
# tconst                0
# titleType             0
# primaryTitle          0
# startYear             0
# genres                0
# averageRating    409094
# numVotes         409094
# dtype: int64

# %%
df5 = df4.dropna()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310234 entries, 0 to 719318
# Data columns (total 7 columns):
# tconst           310234 non-null object
# titleType        310234 non-null object
# primaryTitle     310234 non-null object
# startYear        310234 non-null int16
# genres           310234 non-null object
# averageRating    310234 non-null float64
# numVotes         310234 non-null float64
# dtypes: float64(2), int16(1), object(4)
# memory usage: 17.2+ MB

# %%
df5.head(20)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0   tt0015724     movie                                      Dama de noche
# 1   tt0016906     movie                                         Frivolinas
# 2   tt0021617     movie                                  Arizona Territory
# 3   tt0022064     movie                                      Lebbra bianca
# 4   tt0023331     movie                                    Pesn o geroyakh
# 5   tt0025557     movie                  El negro que tenía el alma blanca
# 6   tt0030998     movie                            You're Only Young Twice
# 7   tt0031458     movie                           El huésped del sevillano
# 8   tt0031603     movie  Made in Germany - Die dramatische Geschichte d...
# 9   tt0032787     movie                                    Mi noche triste
# 11  tt0035423     movie                                     Kate & Leopold
# ...

# %%
df5.to_csv("data_films.csv",index=False)

# %%
genr = df5.genres.unique()

# %%
genr
# Out:
# array(['Drama,Mystery,Romance', 'Comedy,Musical',
#        'Action,Adventure,Western', ..., 'Documentary,Family,Sci-Fi',
#        'Game-Show,Sport,Talk-Show', 'Family,Musical,News'], dtype=object)

# %%
for row in genr:
    print(row)
# Out:
# Drama,Mystery,Romance
# Comedy,Musical
# Action,Adventure,Western
# Drama
# Documentary
# Drama,Musical
# Comedy
# Biography,Drama
# Comedy,Fantasy,Romance
# Drama,War
# Drama,Family
# Action,Adventure,Mystery
# Crime
# Drama,History
# Documentary,War
# Adventure,History
# Comedy,Drama
# Drama,Musical,Romance
# Comedy,Fantasy
# Adventure,Drama,History
# Western
# Drama,Romance
# Crime,Film-Noir,Thriller
# Action,Adventure,Romance
# Crime,Drama,Thriller
# Comedy,Drama,Family
# Biography,Drama,History
# Comedy,Romance,Western
# Action,Music,Western
# Fantasy
# Drama,Film-Noir
# Drama,Fantasy,Romance
# Musical
# Comedy,Crime
# Comedy,Drama,Musical
# Adventure
# Adventure,Crime,Drama
# Crime,Drama
# Action,Adventure,Comedy
# Action,Adventure,Music
# Drama,Sport,Thriller
# Crime,Drama,Film-Noir
# Adventure,Comedy
# Action,Comedy,Music
# Comedy,Romance
# Drama,History,War
# Comedy,Family
# Biography,Comedy,Musical
# Adventure,Comedy,Romance
# Action,Adventure,Crime
# Musical,Romance
# ...

# %%
len(genr)
# Out:
# 1503
